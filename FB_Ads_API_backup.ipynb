# %%
#Dùng để get dữ liệu từ Facebook API
from facebook_business.api import FacebookAdsApi
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.adcreative import AdCreative
import requests

#Dùng để get thời gian
from datetime import datetime, timedelta
import time

#Dùng để work với gg sheet
import pygsheets

#Một số thư viện khác
import pandas as pd
# %run LookupValue.ipynb

# %%
#Mở gg sheet
client = pygsheets.authorize(service_file = r'C:\Users\Tường\Documents\FACEBOOK-API-BOT--main\maido-agency-e7cc6f08cb95.json')

sh = client.open('MAIDO - DB MAGIC DATA')
wks = sh.worksheet_by_title('AdAccounts')

#Lấy dữ liệu từ CampaignPeriod và lưu thành DataFrame
df = wks.get_as_df()

#Loại bỏ những dòng có access_token là null
drop_rows = df[df['access_token']==''].index
df.drop(drop_rows,axis = 0,inplace = True)

df['start_date'] = pd.to_datetime(df['start_date'])

# %%
def df_from_insights(insights,access_token):
  data = pd.DataFrame(columns = ['ad_id','date','account_name','campaign_name','adset_name','reach','impressions','cost','post_engagement','message_ads','page_like_ads','post_body','post_url','post_image'])

  #Tạo ra các list rỗng để append giá trị
  date = []
  campaign_name = []
  adset_name = []
  reach = []
  impressions = []
  cost = []
  post_engagement = []
  mess_ads = []
  page_likes_ads = []
  ad_id = []
  account_name = []
  #Lặp qua tất cả các giá trị lấy về được từ get_insights(), nó bao gồm nhiều dict, mỗi dict là một dòng dữ liệu
  for i in insights:
    campaign_name.append(i['campaign_name'])
    adset_name.append(i['adset_name'])
    ad_id.append(i['ad_id'])
    date.append(datetime.strptime(i['date_start'], '%Y-%m-%d')) 
    account_name.append(i['account_name'])
    reach.append(i['reach'])
    impressions.append(i['impressions'])
    cost.append(i['spend'])
    #Lấy ra post_engagement của bài ads, nếu không có => trả về 00
    try:
      value = ""
      for k in i['actions']:
        if k['action_type'] == 'post_engagement':
          value = k['value']
      post_engagement.append(value)
    except KeyError:
      post_engagement.append("")

    #Lấy ra message_ads của bài ads, nếu không có => trả về 00
    try:
      value = ""
      for k in i['actions']:
        if k['action_type'] == 'onsite_conversion.messaging_conversation_started_7d':
          value = k['value']
      mess_ads.append(value)
    except KeyError:
      mess_ads.append("")

    #Lấy ra page_likes_ads của bài ads, nếu không có => trả về 00
    try:
      value = ""
      for k in i['actions']:
        if k['action_type'] == 'like':
          value = k['value']
      page_likes_ads.append(value)
    except KeyError:
      page_likes_ads.append("")

  #Gom tất cả lại thành 1 DataFrame
  df = pd.DataFrame({"campaign_name":campaign_name,
                      "adset_name":adset_name,
                      "account_name": account_name,
                      "ad_id":ad_id,
                      "date":date,
                      "reach":reach,
                      "impressions":impressions,
                      "cost":cost,
                      "post_engagement":post_engagement,
                      "message_ads":mess_ads,
                      "page_like_ads":page_likes_ads}, 
                      columns = ['ad_id','date','account_name','campaign_name','adset_name','reach','impressions','cost','post_engagement','message_ads','page_like_ads'])

  #Tạo list rỗng để append các giá trị
  ad_body = []
  post_url = []
  image_url = []

  #Lấy về các thông tin bằng cách requests graph api của Facebook, tham khảo thêm tại https://developers.facebook.com/docs/graph-api/
  for i in df['ad_id']:
    query = '''https://graph.facebook.com/v15.0/{ad_id}?fields=adcreatives{body,effective_object_story_id,thumbnail_url}
              &access_token={access_token}'''

    run_query = query.replace("{ad_id}",str(i)).replace('{access_token}',str(access_token))
    r = requests.get(run_query)     #Thay id của từng bài post vào để requests
    adcreatives = r.json()          #Thêm .json() để trả về các chuỗi có cả emoji
    #Lấy ra ad_body bằng cách index vào dictionary và thêm vào list 
    try:
      ad_body.append(adcreatives['adcreatives']['data'][0]["body"])
    except KeyError:
      ad_body.append("")

    #Lấy ra post_url bằng cách index vào dictionary và thêm vào list, post_url =  www.facebook.com/{effective_object_story_id}
    try:
      post_url.append("www.facebook.com/"+adcreatives['adcreatives']['data'][0]["effective_object_story_id"])
    except KeyError:
      post_url.append("")

    #Lấy ra image_url bằng cách index vào dictionary và thêm vào list, vì chưa lấy được image nên dùng thumbnail_url để thay thế 
    try:
      image_url.append(adcreatives['adcreatives']['data'][0]["thumbnail_url"])
    except KeyError:
      image_url.append("")
  

  #Nối list thành 3 cột trong DataFrame
  df['post_body'] = ad_body
  df['post_url'] = post_url
  df['post_image'] = image_url
  data = pd.concat([data,df], axis =0)
  return data

# %%
def get_data(id, app_id, app_secret,access_token,start_date):

  output = pd.DataFrame(columns = ['date','account_name','campaign_name','adset_name','reach','impressions','cost','post_engagement','message_ads','page_like_ads','post_body','post_url','post_image'])


  #Gọi Facebook API
  FacebookAdsApi.init(app_id, app_secret, access_token)
  print("init")
  
  #Các trường mong muốn trả về
  fields = [
  'account_name',             #Tên tài khoản
  'campaign_name',            #Tên campaign
  'adset_name',               #Tên adset
  'ad_id',                    #Mã bài ad => Dùng để lấy về body, url, image_url
  'actions',                  #Tương tác bài ads, có nhiều trường nhưng chỉ sử dụng post_engagement, onsite_conversion.messaging_conversation_started_7d, likes
  'reach',                    #Reach
  'impressions',              #Impressions
  'spend']                    #Cost
    
  #Các parameters truyền vào
  params = {
      'level': 'ad',              #lấy dữ liệu theo level: có 4 level là adaccount, campaign, adset, ad. Cái này đang lấy theo level ad
      'limit':10000,              #giới hạn số lượng kết quả trả về
      'time_range[since]':'',     #Ngày bắt đầu
      'time_range[until]':'',     #Ngày kết thúc
  }

  #Khởi tạo danh sách ngày
  today =  datetime.strptime(datetime.today().strftime('%Y-%m-%d'),'%Y-%m-%d')
  if str(start_date) == "":
    date_lst = [datetime.strptime('2022-10-01', '%Y-%m-%d')]
  elif str(start_date) == "NaT":
    date_lst =[today]
  else:
    date_lst = [start_date]
  
  while  date_lst[-1]< today:
    date_lst.append(date_lst[-1] + timedelta(1))

  for i in range(0,len(date_lst)):
    date_lst[i] = str(date_lst[i]).split(' ')[0]

  #Lặp qua từng ngày trong date_lst để lấy dữ liệu theo daily
  print(f"Period: {date_lst[0]} - {date_lst[-1]}")
  for i in date_lst:
    print('Lấy data ngày:',i)

    #Thay ngày vào params
    params['time_range[since]'] = i
    params['time_range[until]'] = i

    #Lấy insights
    insights = AdAccount(id).get_insights(
        params = params,
        fields = fields
    )
    print('Lượng Data:',len(insights))


    #Nếu insights > 0 thì lấy dữ liệu và lưu thành DataFrame
    if len(insights) >0:
      data_daily = df_from_insights(insights,access_token)
      print('Đã lấy về được:',len(data_daily))
      output = pd.concat([output,data_daily],axis=0)

  #Sửa đổi thứ tự cột trước khi return
  return output[['date','account_name','campaign_name','adset_name','post_body','post_url','post_image','reach','impressions','cost','post_engagement','message_ads','page_like_ads']]

# %%
print("Bắt đầu lấy dữ liệu FB Ads")
output = pd.DataFrame(columns = ['date','account_name','campaign_name','adset_name','post_body','post_url','post_image','reach','impressions','cost','post_engagement','message_ads','page_like_ads'])
start_lst = []
#Lặp qua các account trong DataFrame để lấy dữ liệu
for i in range(0,len(df)):
  print('Đang lấy data từ:',df.iloc[i]['account_name'])

  #Gọi hàm get_data để lấy dữ liệu
  adaccount_data = get_data(df.iloc[i]['account_id'],df.iloc[i]['app_id'],df.iloc[i]['app_secret'],df.iloc[i]['access_token'],df.iloc[i]['start_date'])

  #Lấy ra ngày đầu tiên có data nếu ngày đó chưa xuất hiện trong sheet để lần thứ 2 chạy ít lại
  if len(adaccount_data) >0:
    start_lst.append(adaccount_data['date'].min())
  else:
    start_lst.append("")
  


  #Nối dữ liệu vừa tìm được vào output
  output = pd.concat([output,adaccount_data], axis =0)


  print('Xong account:', df.iloc[i]['account_name'], '- Lượng Data:', len(adaccount_data))
  print('---------------------')
  print('')

#Lấy các thông tin khác
output['cost'] = [str(cost).replace(',','') if cost != '' else 0 for cost in output['cost']]
output['cost'] = output['cost'].astype('float')

output['result'] = get_result(output)
output['month'] = get_month(output)
output['service_code'] = get_service_code(output)
output = get_from_settings(output)
output = get_page_data(output)
output['phone_number'] = ["0"+str(i) for i in output['phone_number']]
output.fillna(0.0,inplace=True)
output.drop_duplicates(inplace = True)
#Ghi lại ngày bắt đầu vào sheet
df['start_date'] = start_lst  
wks.set_dataframe(df,start="A2",copy_head=False)

#Tìm vị trí để ghi
print('Không chỉnh sửa trong thời gian này')
sh1 = client.open('MAIDO - DB MAGIC DATA')

#Ghi vào gg sheet
columns_order = ['service_code','page_name','month','date','account_name','campaign_name','adset_name','post_body','post_url','post_image','reach','impressions','cost','post_engagement','message_ads','page_like_ads','message_page','page_like_organic','cost_external','phone_number','result']
write_sheet = sh1.worksheet_by_title('Data Raw')
output.sort_values(by = 'date',inplace = True)
write_sheet.set_dataframe(output[columns_order],start = "A2",copy_head =False)

columns_order = ['service_code','page_name','month','date','account_name','campaign_name','adset_name','post_body','post_url','post_image','reach','impressions','cost','post_engagement','message_ads','page_like_ads','cost_external','phone_number','result']
sh2 = client.open('MAIDO - ADS PERFORMANCE - DATA')
ads_performance = sh2.worksheet_by_title('2. Data Raw - FB Ads')
ads_performance.set_dataframe(output[columns_order],start = "A2",copy_head =False)

#Xong rồi đó, nghỉ 1 tiếng rồi chạy lại
print('------DONE------')
print("Nghỉ 1 tiếng rồi chạy tiếp") 
print('')
# Out:
# Bắt đầu lấy dữ liệu FB Ads
# Đang lấy data từ: Maido Agency Co., LTD
# init
# Period: 2023-01-07 - 2023-02-08
# Lấy data ngày: 2023-01-07
# Lượng Data: 32
# Đã lấy về được: 32
# Lấy data ngày: 2023-01-08
# Lượng Data: 40
# Đã lấy về được: 40
# Lấy data ngày: 2023-01-09
# Lượng Data: 52
# Đã lấy về được: 52
# Lấy data ngày: 2023-01-10
# Lượng Data: 55
# Đã lấy về được: 55
# Lấy data ngày: 2023-01-11
# Lượng Data: 52
# Đã lấy về được: 52
# Lấy data ngày: 2023-01-12
# Lượng Data: 47
# Đã lấy về được: 47
# Lấy data ngày: 2023-01-13
# Lượng Data: 102
# Đã lấy về được: 102
# Lấy data ngày: 2023-01-14
# Lượng Data: 75
# Đã lấy về được: 75
# Lấy data ngày: 2023-01-15
# Lượng Data: 38
# Đã lấy về được: 38
# Lấy data ngày: 2023-01-16
# Lượng Data: 37
# Đã lấy về được: 37
# Lấy data ngày: 2023-01-17
# Lượng Data: 31
# Đã lấy về được: 31
# Lấy data ngày: 2023-01-18
# Lượng Data: 19
# Đã lấy về được: 19
# Lấy data ngày: 2023-01-19
# Lượng Data: 7
# Đã lấy về được: 7
# Lấy data ngày: 2023-01-20
# Lượng Data: 0
# Lấy data ngày: 2023-01-21
# Lượng Data: 0
# Lấy data ngày: 2023-01-22
# Lượng Data: 0
# Lấy data ngày: 2023-01-23
# Lượng Data: 0
# Lấy data ngày: 2023-01-24
# Lượng Data: 0
# Lấy data ngày: 2023-01-25
# Lượng Data: 12
# Đã lấy về được: 12
# Lấy data ngày: 2023-01-26
# Lượng Data: 12
# Đã lấy về được: 12
# Lấy data ngày: 2023-01-27
# Lượng Data: 12
# Đã lấy về được: 12
# Lấy data ngày: 2023-01-28
# Lượng Data: 12
# Đã lấy về được: 12
# Lấy data ngày: 2023-01-29
# Lượng Data: 12
# Đã lấy về được: 12
# Lấy data ngày: 2023-01-30
# Lượng Data: 33
# Đã lấy về được: 33
# Lấy data ngày: 2023-01-31
# Lượng Data: 49
# Đã lấy về được: 49
# Lấy data ngày: 2023-02-01
# Lượng Data: 63
# Đã lấy về được: 63
# Lấy data ngày: 2023-02-02
# Lượng Data: 92
# Đã lấy về được: 92
# Lấy data ngày: 2023-02-03
# Lượng Data: 118
# Đã lấy về được: 118
# Lấy data ngày: 2023-02-04
# Lượng Data: 100
# Đã lấy về được: 100
# Lấy data ngày: 2023-02-05
# Lượng Data: 113
# Đã lấy về được: 113
# Lấy data ngày: 2023-02-06
# Lượng Data: 85
# Đã lấy về được: 85
# Lấy data ngày: 2023-02-07
# Lượng Data: 101
# Đã lấy về được: 101
# Lấy data ngày: 2023-02-08
# Lượng Data: 102
# Đã lấy về được: 102
# Xong account: Maido Agency Co., LTD - Lượng Data: 1503
# ---------------------
#
# Đang lấy data từ: Trang Ho
# init
# Period: 2022-12-27 - 2023-02-08
# Lấy data ngày: 2022-12-27
# Lượng Data: 47
# Đã lấy về được: 47
# Lấy data ngày: 2022-12-28
# Lượng Data: 78
# Đã lấy về được: 78
# Lấy data ngày: 2022-12-29
# Lượng Data: 111
# Đã lấy về được: 111
# Lấy data ngày: 2022-12-30
# Lượng Data: 124
# Đã lấy về được: 124
# Lấy data ngày: 2022-12-31
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2023-01-01
# Lượng Data: 0
# Lấy data ngày: 2023-01-02
# Lượng Data: 0
# Lấy data ngày: 2023-01-03
# Lượng Data: 0
# Lấy data ngày: 2023-01-04
# Lượng Data: 0
# Lấy data ngày: 2023-01-05
# Lượng Data: 0
# Lấy data ngày: 2023-01-06
# Lượng Data: 0
# Lấy data ngày: 2023-01-07
# Lượng Data: 0
# Lấy data ngày: 2023-01-08
# Lượng Data: 0
# Lấy data ngày: 2023-01-09
# Lượng Data: 0
# Lấy data ngày: 2023-01-10
# Lượng Data: 0
# Lấy data ngày: 2023-01-11
# Lượng Data: 0
# Lấy data ngày: 2023-01-12
# Lượng Data: 0
# Lấy data ngày: 2023-01-13
# Lượng Data: 0
# Lấy data ngày: 2023-01-14
# Lượng Data: 0
# Lấy data ngày: 2023-01-15
# Lượng Data: 0
# Lấy data ngày: 2023-01-16
# Lượng Data: 0
# Lấy data ngày: 2023-01-17
# Lượng Data: 0
# Lấy data ngày: 2023-01-18
# Lượng Data: 0
# Lấy data ngày: 2023-01-19
# Lượng Data: 0
# Lấy data ngày: 2023-01-20
# Lượng Data: 0
# Lấy data ngày: 2023-01-21
# Lượng Data: 0
# Lấy data ngày: 2023-01-22
# Lượng Data: 0
# Lấy data ngày: 2023-01-23
# Lượng Data: 0
# Lấy data ngày: 2023-01-24
# Lượng Data: 0
# Lấy data ngày: 2023-01-25
# Lượng Data: 0
# Lấy data ngày: 2023-01-26
# Lượng Data: 0
# Lấy data ngày: 2023-01-27
# Lượng Data: 0
# Lấy data ngày: 2023-01-28
# Lượng Data: 0
# Lấy data ngày: 2023-01-29
# Lượng Data: 0
# Lấy data ngày: 2023-01-30
# Lượng Data: 0
# Lấy data ngày: 2023-01-31
# Lượng Data: 0
# Lấy data ngày: 2023-02-01
# Lượng Data: 0
# Lấy data ngày: 2023-02-02
# Lượng Data: 0
# Lấy data ngày: 2023-02-03
# Lượng Data: 0
# Lấy data ngày: 2023-02-04
# Lượng Data: 0
# Lấy data ngày: 2023-02-05
# Lượng Data: 0
# Lấy data ngày: 2023-02-06
# Lượng Data: 0
# Lấy data ngày: 2023-02-07
# Lượng Data: 0
# Lấy data ngày: 2023-02-08
# Lượng Data: 0
# Xong account: Trang Ho - Lượng Data: 361
# ---------------------
#
# Đang lấy data từ: Công Ty TNHH XNK Á Âu
# init
# Period: 2023-01-12 - 2023-02-08
# Lấy data ngày: 2023-01-12
# Lượng Data: 6
# Đã lấy về được: 6
# Lấy data ngày: 2023-01-13
# Lượng Data: 15
# Đã lấy về được: 15
# Lấy data ngày: 2023-01-14
# Lượng Data: 7
# Đã lấy về được: 7
# Lấy data ngày: 2023-01-15
# Lượng Data: 6
# Đã lấy về được: 6
# Lấy data ngày: 2023-01-16
# Lượng Data: 5
# Đã lấy về được: 5
# Lấy data ngày: 2023-01-17
# Lượng Data: 4
# Đã lấy về được: 4
# Lấy data ngày: 2023-01-18
# Lượng Data: 2
# Đã lấy về được: 2
# Lấy data ngày: 2023-01-19
# Lượng Data: 2
# Đã lấy về được: 2
# Lấy data ngày: 2023-01-20
# Lượng Data: 0
# Lấy data ngày: 2023-01-21
# Lượng Data: 0
# Lấy data ngày: 2023-01-22
# Lượng Data: 0
# Lấy data ngày: 2023-01-23
# Lượng Data: 0
# Lấy data ngày: 2023-01-24
# Lượng Data: 0
# Lấy data ngày: 2023-01-25
# Lượng Data: 0
# Lấy data ngày: 2023-01-26
# Lượng Data: 0
# Lấy data ngày: 2023-01-27
# Lượng Data: 0
# Lấy data ngày: 2023-01-28
# Lượng Data: 0
# Lấy data ngày: 2023-01-29
# Lượng Data: 0
# Lấy data ngày: 2023-01-30
# Lượng Data: 3
# Đã lấy về được: 3
# Lấy data ngày: 2023-01-31
# Lượng Data: 4
# Đã lấy về được: 4
# Lấy data ngày: 2023-02-01
# Lượng Data: 6
# Đã lấy về được: 6
# Lấy data ngày: 2023-02-02
# Lượng Data: 6
# Đã lấy về được: 6
# Lấy data ngày: 2023-02-03
# Lượng Data: 11
# Đã lấy về được: 11
# Lấy data ngày: 2023-02-04
# Lượng Data: 11
# Đã lấy về được: 11
# Lấy data ngày: 2023-02-05
# Lượng Data: 24
# Đã lấy về được: 24
# Lấy data ngày: 2023-02-06
# Lượng Data: 21
# Đã lấy về được: 21
# Lấy data ngày: 2023-02-07
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-02-08
# Lượng Data: 24
# Đã lấy về được: 24
# Xong account: Công Ty TNHH XNK Á Âu - Lượng Data: 175
# ---------------------
#
# Đang lấy data từ: Maido Agency
# init
# Period: 2022-12-13 - 2023-02-08
# Lấy data ngày: 2022-12-13
# Lượng Data: 37
# Đã lấy về được: 37
# Lấy data ngày: 2022-12-14
# Lượng Data: 71
# Đã lấy về được: 71
# Lấy data ngày: 2022-12-15
# Lượng Data: 63
# Đã lấy về được: 63
# Lấy data ngày: 2022-12-16
# Lượng Data: 65
# Đã lấy về được: 65
# Lấy data ngày: 2022-12-17
# Lượng Data: 79
# Đã lấy về được: 79
# Lấy data ngày: 2022-12-18
# Lượng Data: 54
# Đã lấy về được: 54
# Lấy data ngày: 2022-12-19
# Lượng Data: 59
# Đã lấy về được: 59
# Lấy data ngày: 2022-12-20
# Lượng Data: 39
# Đã lấy về được: 39
# Lấy data ngày: 2022-12-21
# Lượng Data: 63
# Đã lấy về được: 63
# Lấy data ngày: 2022-12-22
# Lượng Data: 45
# Đã lấy về được: 45
# Lấy data ngày: 2022-12-23
# Lượng Data: 69
# Đã lấy về được: 69
# Lấy data ngày: 2022-12-24
# Lượng Data: 80
# Đã lấy về được: 80
# Lấy data ngày: 2022-12-25
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2022-12-26
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2022-12-27
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2022-12-28
# Lượng Data: 0
# Lấy data ngày: 2022-12-29
# Lượng Data: 0
# Lấy data ngày: 2022-12-30
# Lượng Data: 0
# Lấy data ngày: 2022-12-31
# Lượng Data: 0
# Lấy data ngày: 2023-01-01
# Lượng Data: 0
# Lấy data ngày: 2023-01-02
# Lượng Data: 0
# Lấy data ngày: 2023-01-03
# Lượng Data: 64
# Đã lấy về được: 64
# Lấy data ngày: 2023-01-04
# Lượng Data: 82
# Đã lấy về được: 82
# Lấy data ngày: 2023-01-05
# Lượng Data: 76
# Đã lấy về được: 76
# Lấy data ngày: 2023-01-06
# Lượng Data: 77
# Đã lấy về được: 77
# Lấy data ngày: 2023-01-07
# Lượng Data: 31
# Đã lấy về được: 31
# Lấy data ngày: 2023-01-08
# Lượng Data: 0
# Lấy data ngày: 2023-01-09
# Lượng Data: 0
# Lấy data ngày: 2023-01-10
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2023-01-11
# Lượng Data: 0
# Lấy data ngày: 2023-01-12
# Lượng Data: 0
# Lấy data ngày: 2023-01-13
# Lượng Data: 0
# Lấy data ngày: 2023-01-14
# Lượng Data: 0
# Lấy data ngày: 2023-01-15
# Lượng Data: 0
# Lấy data ngày: 2023-01-16
# Lượng Data: 0
# Lấy data ngày: 2023-01-17
# Lượng Data: 0
# Lấy data ngày: 2023-01-18
# Lượng Data: 0
# Lấy data ngày: 2023-01-19
# Lượng Data: 0
# Lấy data ngày: 2023-01-20
# Lượng Data: 0
# Lấy data ngày: 2023-01-21
# Lượng Data: 0
# Lấy data ngày: 2023-01-22
# Lượng Data: 0
# Lấy data ngày: 2023-01-23
# Lượng Data: 0
# Lấy data ngày: 2023-01-24
# Lượng Data: 0
# Lấy data ngày: 2023-01-25
# Lượng Data: 0
# Lấy data ngày: 2023-01-26
# Lượng Data: 0
# Lấy data ngày: 2023-01-27
# Lượng Data: 0
# Lấy data ngày: 2023-01-28
# Lượng Data: 0
# Lấy data ngày: 2023-01-29
# Lượng Data: 0
# Lấy data ngày: 2023-01-30
# Lượng Data: 0
# Lấy data ngày: 2023-01-31
# Lượng Data: 0
# Lấy data ngày: 2023-02-01
# Lượng Data: 0
# Lấy data ngày: 2023-02-02
# Lượng Data: 0
# Lấy data ngày: 2023-02-03
# Lượng Data: 0
# Lấy data ngày: 2023-02-04
# Lượng Data: 0
# Lấy data ngày: 2023-02-05
# Lượng Data: 0
# Lấy data ngày: 2023-02-06
# Lượng Data: 0
# Lấy data ngày: 2023-02-07
# Lượng Data: 0
# Lấy data ngày: 2023-02-08
# Lượng Data: 0
# Xong account: Maido Agency - Lượng Data: 1058
# ---------------------
#
# Đang lấy data từ: The Ruong
# init
# Period: 2022-12-13 - 2023-02-08
# Lấy data ngày: 2022-12-13
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2022-12-14
# Lượng Data: 27
# Đã lấy về được: 27
# Lấy data ngày: 2022-12-15
# Lượng Data: 27
# Đã lấy về được: 27
# Lấy data ngày: 2022-12-16
# Lượng Data: 26
# Đã lấy về được: 26
# Lấy data ngày: 2022-12-17
# Lượng Data: 26
# Đã lấy về được: 26
# Lấy data ngày: 2022-12-18
# Lượng Data: 26
# Đã lấy về được: 26
# Lấy data ngày: 2022-12-19
# Lượng Data: 26
# Đã lấy về được: 26
# Lấy data ngày: 2022-12-20
# Lượng Data: 26
# Đã lấy về được: 26
# Lấy data ngày: 2022-12-21
# Lượng Data: 26
# Đã lấy về được: 26
# Lấy data ngày: 2022-12-22
# Lượng Data: 25
# Đã lấy về được: 25
# Lấy data ngày: 2022-12-23
# Lượng Data: 14
# Đã lấy về được: 14
# Lấy data ngày: 2022-12-24
# Lượng Data: 10
# Đã lấy về được: 10
# Lấy data ngày: 2022-12-25
# Lượng Data: 9
# Đã lấy về được: 9
# Lấy data ngày: 2022-12-26
# Lượng Data: 10
# Đã lấy về được: 10
# Lấy data ngày: 2022-12-27
# Lượng Data: 23
# Đã lấy về được: 23
# Lấy data ngày: 2022-12-28
# Lượng Data: 2
# Đã lấy về được: 2
# Lấy data ngày: 2022-12-29
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2022-12-30
# Lượng Data: 0
# Lấy data ngày: 2022-12-31
# Lượng Data: 28
# Đã lấy về được: 28
# Lấy data ngày: 2023-01-01
# Lượng Data: 27
# Đã lấy về được: 27
# Lấy data ngày: 2023-01-02
# Lượng Data: 26
# Đã lấy về được: 26
# Lấy data ngày: 2023-01-03
# Lượng Data: 27
# Đã lấy về được: 27
# Lấy data ngày: 2023-01-04
# Lượng Data: 24
# Đã lấy về được: 24
# Lấy data ngày: 2023-01-05
# Lượng Data: 23
# Đã lấy về được: 23
# Lấy data ngày: 2023-01-06
# Lượng Data: 21
# Đã lấy về được: 21
# Lấy data ngày: 2023-01-07
# Lượng Data: 5
# Đã lấy về được: 5
# Lấy data ngày: 2023-01-08
# Lượng Data: 0
# Lấy data ngày: 2023-01-09
# Lượng Data: 0
# Lấy data ngày: 2023-01-10
# Lượng Data: 0
# Lấy data ngày: 2023-01-11
# Lượng Data: 3
# Đã lấy về được: 3
# Lấy data ngày: 2023-01-12
# Lượng Data: 0
# Lấy data ngày: 2023-01-13
# Lượng Data: 0
# Lấy data ngày: 2023-01-14
# Lượng Data: 0
# Lấy data ngày: 2023-01-15
# Lượng Data: 0
# Lấy data ngày: 2023-01-16
# Lượng Data: 0
# Lấy data ngày: 2023-01-17
# Lượng Data: 0
# Lấy data ngày: 2023-01-18
# Lượng Data: 0
# Lấy data ngày: 2023-01-19
# Lượng Data: 0
# Lấy data ngày: 2023-01-20
# Lượng Data: 0
# Lấy data ngày: 2023-01-21
# Lượng Data: 0
# Lấy data ngày: 2023-01-22
# Lượng Data: 0
# Lấy data ngày: 2023-01-23
# Lượng Data: 0
# Lấy data ngày: 2023-01-24
# Lượng Data: 0
# Lấy data ngày: 2023-01-25
# Lượng Data: 0
# Lấy data ngày: 2023-01-26
# Lượng Data: 0
# Lấy data ngày: 2023-01-27
# Lượng Data: 0
# Lấy data ngày: 2023-01-28
# Lượng Data: 0
# Lấy data ngày: 2023-01-29
# Lượng Data: 0
# Lấy data ngày: 2023-01-30
# Lượng Data: 0
# Lấy data ngày: 2023-01-31
# Lượng Data: 0
# Lấy data ngày: 2023-02-01
# Lượng Data: 0
# Lấy data ngày: 2023-02-02
# Lượng Data: 0
# Lấy data ngày: 2023-02-03
# Lượng Data: 0
# Lấy data ngày: 2023-02-04
# Lượng Data: 0
# Lấy data ngày: 2023-02-05
# Lượng Data: 0
# Lấy data ngày: 2023-02-06
# Lượng Data: 0
# Lấy data ngày: 2023-02-07
# Lượng Data: 0
# Lấy data ngày: 2023-02-08
# Lượng Data: 0
# Xong account: The Ruong - Lượng Data: 506
# ---------------------
#
# Đang lấy data từ: Khoi Nguyen
# init
# Period: 2022-12-22 - 2023-02-08
# Lấy data ngày: 2022-12-22
# Lượng Data: 26
# Đã lấy về được: 26
# Lấy data ngày: 2022-12-23
# Lượng Data: 0
# Lấy data ngày: 2022-12-24
# Lượng Data: 0
# Lấy data ngày: 2022-12-25
# Lượng Data: 0
# Lấy data ngày: 2022-12-26
# Lượng Data: 0
# Lấy data ngày: 2022-12-27
# Lượng Data: 0
# Lấy data ngày: 2022-12-28
# Lượng Data: 0
# Lấy data ngày: 2022-12-29
# Lượng Data: 0
# Lấy data ngày: 2022-12-30
# Lượng Data: 0
# Lấy data ngày: 2022-12-31
# Lượng Data: 0
# Lấy data ngày: 2023-01-01
# Lượng Data: 0
# Lấy data ngày: 2023-01-02
# Lượng Data: 0
# Lấy data ngày: 2023-01-03
# Lượng Data: 0
# Lấy data ngày: 2023-01-04
# Lượng Data: 0
# Lấy data ngày: 2023-01-05
# Lượng Data: 0
# Lấy data ngày: 2023-01-06
# Lượng Data: 0
# Lấy data ngày: 2023-01-07
# Lượng Data: 0
# Lấy data ngày: 2023-01-08
# Lượng Data: 0
# Lấy data ngày: 2023-01-09
# Lượng Data: 0
# Lấy data ngày: 2023-01-10
# Lượng Data: 0
# Lấy data ngày: 2023-01-11
# Lượng Data: 0
# Lấy data ngày: 2023-01-12
# Lượng Data: 0
# Lấy data ngày: 2023-01-13
# Lượng Data: 0
# Lấy data ngày: 2023-01-14
# Lượng Data: 0
# Lấy data ngày: 2023-01-15
# Lượng Data: 0
# Lấy data ngày: 2023-01-16
# Lượng Data: 0
# Lấy data ngày: 2023-01-17
# Lượng Data: 0
# Lấy data ngày: 2023-01-18
# Lượng Data: 0
# Lấy data ngày: 2023-01-19
# Lượng Data: 0
# Lấy data ngày: 2023-01-20
# Lượng Data: 0
# Lấy data ngày: 2023-01-21
# Lượng Data: 0
# Lấy data ngày: 2023-01-22
# Lượng Data: 0
# Lấy data ngày: 2023-01-23
# Lượng Data: 0
# Lấy data ngày: 2023-01-24
# Lượng Data: 0
# Lấy data ngày: 2023-01-25
# Lượng Data: 0
# Lấy data ngày: 2023-01-26
# Lượng Data: 0
# Lấy data ngày: 2023-01-27
# Lượng Data: 0
# Lấy data ngày: 2023-01-28
# Lượng Data: 0
# Lấy data ngày: 2023-01-29
# Lượng Data: 0
# Lấy data ngày: 2023-01-30
# Lượng Data: 0
# Lấy data ngày: 2023-01-31
# Lượng Data: 0
# Lấy data ngày: 2023-02-01
# Lượng Data: 0
# Lấy data ngày: 2023-02-02
# Lượng Data: 0
# Lấy data ngày: 2023-02-03
# Lượng Data: 0
# Lấy data ngày: 2023-02-04
# Lượng Data: 0
# Lấy data ngày: 2023-02-05
# Lượng Data: 0
# Lấy data ngày: 2023-02-06
# Lượng Data: 0
# Lấy data ngày: 2023-02-07
# Lượng Data: 0
# Lấy data ngày: 2023-02-08
# Lượng Data: 0
# Xong account: Khoi Nguyen - Lượng Data: 26
# ---------------------
#
# Đang lấy data từ: Tan Nguyen
# init
# Period: 2023-01-10 - 2023-02-08
# Lấy data ngày: 2023-01-10
# Lượng Data: 5
# Đã lấy về được: 5
# Lấy data ngày: 2023-01-11
# Lượng Data: 9
# Đã lấy về được: 9
# Lấy data ngày: 2023-01-12
# Lượng Data: 12
# Đã lấy về được: 12
# Lấy data ngày: 2023-01-13
# Lượng Data: 0
# Lấy data ngày: 2023-01-14
# Lượng Data: 0
# Lấy data ngày: 2023-01-15
# Lượng Data: 0
# Lấy data ngày: 2023-01-16
# Lượng Data: 0
# Lấy data ngày: 2023-01-17
# Lượng Data: 0
# Lấy data ngày: 2023-01-18
# Lượng Data: 0
# Lấy data ngày: 2023-01-19
# Lượng Data: 0
# Lấy data ngày: 2023-01-20
# Lượng Data: 0
# Lấy data ngày: 2023-01-21
# Lượng Data: 0
# Lấy data ngày: 2023-01-22
# Lượng Data: 0
# Lấy data ngày: 2023-01-23
# Lượng Data: 0
# Lấy data ngày: 2023-01-24
# Lượng Data: 0
# Lấy data ngày: 2023-01-25
# Lượng Data: 0
# Lấy data ngày: 2023-01-26
# Lượng Data: 0
# Lấy data ngày: 2023-01-27
# Lượng Data: 0
# Lấy data ngày: 2023-01-28
# Lượng Data: 0
# Lấy data ngày: 2023-01-29
# Lượng Data: 0
# Lấy data ngày: 2023-01-30
# Lượng Data: 0
# Lấy data ngày: 2023-01-31
# Lượng Data: 0
# Lấy data ngày: 2023-02-01
# Lượng Data: 0
# Lấy data ngày: 2023-02-02
# Lượng Data: 0
# Lấy data ngày: 2023-02-03
# Lượng Data: 0
# Lấy data ngày: 2023-02-04
# Lượng Data: 0
# Lấy data ngày: 2023-02-05
# Lượng Data: 0
# Lấy data ngày: 2023-02-06
# Lượng Data: 0
# Lấy data ngày: 2023-02-07
# Lượng Data: 0
# Lấy data ngày: 2023-02-08
# Lượng Data: 0
# Xong account: Tan Nguyen - Lượng Data: 26
# ---------------------
#
# Đang lấy data từ: Công Ty TNHH Quảng Cáo Maido
# init
# Period: 2023-02-08 - 2023-02-08
# Lấy data ngày: 2023-02-08
# Lượng Data: 0
# Xong account: Công Ty TNHH Quảng Cáo Maido - Lượng Data: 0
# ---------------------
#
# Đang lấy data từ: MDADS5
# init
# Period: 2023-01-16 - 2023-02-08
# Lấy data ngày: 2023-01-16
# Lượng Data: 10
# Đã lấy về được: 10
# Lấy data ngày: 2023-01-17
# Lượng Data: 22
# Đã lấy về được: 22
# Lấy data ngày: 2023-01-18
# Lượng Data: 23
# Đã lấy về được: 23
# Lấy data ngày: 2023-01-19
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-01-20
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-01-21
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2023-01-22
# Lượng Data: 2
# Đã lấy về được: 2
# Lấy data ngày: 2023-01-23
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2023-01-24
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2023-01-25
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2023-01-26
# Lượng Data: 0
# Lấy data ngày: 2023-01-27
# Lượng Data: 0
# Lấy data ngày: 2023-01-28
# Lượng Data: 0
# Lấy data ngày: 2023-01-29
# Lượng Data: 0
# Lấy data ngày: 2023-01-30
# Lượng Data: 0
# Lấy data ngày: 2023-01-31
# Lượng Data: 0
# Lấy data ngày: 2023-02-01
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-02-02
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-02-03
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-02-04
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-02-05
# Lượng Data: 17
# Đã lấy về được: 17
# Lấy data ngày: 2023-02-06
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-02-07
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-02-08
# Lượng Data: 18
# Đã lấy về được: 18
# Xong account: MDADS5 - Lượng Data: 240
# ---------------------
#
# Đang lấy data từ: Viet Dang
# init
# Period: 2023-01-13 - 2023-02-08
# Lấy data ngày: 2023-01-13
# Lượng Data: 17
# Đã lấy về được: 17
# Lấy data ngày: 2023-01-14
# Lượng Data: 43
# Đã lấy về được: 43
# Lấy data ngày: 2023-01-15
# Lượng Data: 44
# Đã lấy về được: 44
# Lấy data ngày: 2023-01-16
# Lượng Data: 61
# Đã lấy về được: 61
# Lấy data ngày: 2023-01-17
# Lượng Data: 57
# Đã lấy về được: 57
# Lấy data ngày: 2023-01-18
# Lượng Data: 48
# Đã lấy về được: 48
# Lấy data ngày: 2023-01-19
# Lượng Data: 41
# Đã lấy về được: 41
# Lấy data ngày: 2023-01-20
# Lượng Data: 15
# Đã lấy về được: 15
# Lấy data ngày: 2023-01-21
# Lượng Data: 1
# Đã lấy về được: 1
# Lấy data ngày: 2023-01-22
# Lượng Data: 0
# Lấy data ngày: 2023-01-23
# Lượng Data: 0
# Lấy data ngày: 2023-01-24
# Lượng Data: 0
# Lấy data ngày: 2023-01-25
# Lượng Data: 0
# Lấy data ngày: 2023-01-26
# Lượng Data: 0
# Lấy data ngày: 2023-01-27
# Lượng Data: 0
# Lấy data ngày: 2023-01-28
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-01-29
# Lượng Data: 6
# Đã lấy về được: 6
# Lấy data ngày: 2023-01-30
# Lượng Data: 11
# Đã lấy về được: 11
# Lấy data ngày: 2023-01-31
# Lượng Data: 17
# Đã lấy về được: 17
# Lấy data ngày: 2023-02-01
# Lượng Data: 18
# Đã lấy về được: 18
# Lấy data ngày: 2023-02-02
# Lượng Data: 17
# Đã lấy về được: 17
# Lấy data ngày: 2023-02-03
# Lượng Data: 17
# Đã lấy về được: 17
# Lấy data ngày: 2023-02-04
# Lượng Data: 61
# Đã lấy về được: 61
# Lấy data ngày: 2023-02-05
# Lượng Data: 73
# Đã lấy về được: 73
# Lấy data ngày: 2023-02-06
# Lượng Data: 73
# Đã lấy về được: 73
# Lấy data ngày: 2023-02-07
# Lượng Data: 77
# Đã lấy về được: 77
# Lấy data ngày: 2023-02-08
# Lượng Data: 86
# Đã lấy về được: 86
# Xong account: Viet Dang - Lượng Data: 801
# ---------------------
# /var/folders/4z/6nrk0x1j7xdfdg80zvx9kn100000gn/T/ipykernel_4872/3208213347.py:41: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df['start_date'] = start_lst
# Không chỉnh sửa trong thời gian này
# ------DONE------
# Nghỉ 1 tiếng rồi chạy tiếp
